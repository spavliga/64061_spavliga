# %% [markdown]
# <a href="https://colab.research.google.com/github/spavliga/64061_spavliga/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Steve Pavliga - Assignment 1 - BA-64061-002**

# %% [markdown]
# The original IMBD example is below.

# %%
from tensorflow.keras.datasets import imdb
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(
    num_words=10000)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
train_data[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  2,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  2,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  2,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  2,
#  8,
#  4,
#  107,
#  117,
# ...

# %%
train_labels[0]
# Out:
# 1

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %%
import numpy as np
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
      for j in sequence:
        results[i, j] = 1.
    return results
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
 history = model.fit(partial_x_train,
            partial_y_train,
            epochs=20,
            batch_size=512,
            validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.7111 - loss: 0.5961 - val_accuracy: 0.8024 - val_loss: 0.4459
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8771 - loss: 0.3517 - val_accuracy: 0.8710 - val_loss: 0.3280
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9223 - loss: 0.2416 - val_accuracy: 0.8910 - val_loss: 0.2830
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9400 - loss: 0.1927 - val_accuracy: 0.8898 - val_loss: 0.2735
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9489 - loss: 0.1622 - val_accuracy: 0.8907 - val_loss: 0.2758
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9607 - loss: 0.1310 - val_accuracy: 0.8864 - val_loss: 0.2836
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9651 - loss: 0.1159 - val_accuracy: 0.8847 - val_loss: 0.3071
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
history_dict = history.history

val_acc = history_dict['val_accuracy']
val_loss = history_dict['val_loss']

final_val_acc_base = val_acc[-1]
final_val_loss_base = val_loss[-1]

print(final_val_acc_base)
print(final_val_loss_base)
# Out:
# 0.8720999956130981
# 0.5604092478752136

# %% [markdown]
# **1. You used two hidden layers. Try using one or three hidden layers and see how doing so affects validation and test accuracy.**

# %%
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
 history = model.fit(partial_x_train,
            partial_y_train,
            epochs=20,
            batch_size=512,
            validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.7107 - loss: 0.5867 - val_accuracy: 0.8667 - val_loss: 0.4017
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.8890 - loss: 0.3549 - val_accuracy: 0.8832 - val_loss: 0.3282
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9149 - loss: 0.2748 - val_accuracy: 0.8808 - val_loss: 0.3073
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9311 - loss: 0.2273 - val_accuracy: 0.8852 - val_loss: 0.2900
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9359 - loss: 0.2006 - val_accuracy: 0.8884 - val_loss: 0.2764
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9458 - loss: 0.1773 - val_accuracy: 0.8816 - val_loss: 0.2942
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9535 - loss: 0.1561 - val_accuracy: 0.8868 - val_loss: 0.2813
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss- 1 hidden layer")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy- 1 hidden layer")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
history_dict = history.history

val_acc = history_dict['val_accuracy']
val_loss = history_dict['val_loss']

final_val_acc_11 = val_acc[-1]
final_val_loss_11 = val_loss[-1]

print(final_val_acc_11)
print(final_val_loss_11)
# Out:
# 0.8763999938964844
# 0.3762778639793396

# %% [markdown]
# With 3 hidden layers:

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
 history = model.fit(partial_x_train,
            partial_y_train,
            epochs=20,
            batch_size=512,
            validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6448 - loss: 0.6410 - val_accuracy: 0.8389 - val_loss: 0.4464
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8824 - loss: 0.3751 - val_accuracy: 0.8562 - val_loss: 0.3585
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9161 - loss: 0.2599 - val_accuracy: 0.8855 - val_loss: 0.2897
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9336 - loss: 0.1974 - val_accuracy: 0.8825 - val_loss: 0.2875
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9522 - loss: 0.1546 - val_accuracy: 0.8851 - val_loss: 0.2793
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9540 - loss: 0.1353 - val_accuracy: 0.8854 - val_loss: 0.2937
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.9633 - loss: 0.1157 - val_accuracy: 0.8782 - val_loss: 0.3189
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss- 3 hidden layers")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy- 3 hidden layers")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
history_dict = history.history

val_acc = history_dict['val_accuracy']
val_loss = history_dict['val_loss']

final_val_acc_12 = val_acc[-1]
final_val_loss_12 = val_loss[-1]

print(final_val_acc_12)
print(final_val_loss_12)
# Out:
# 0.8695999979972839
# 0.6332480907440186

# %% [markdown]
# Using one hidden layer appears to have a slightly higher accuracy rate, but has a notably lower validation loss.

# %% [markdown]
# **2. Try using layers with more hidden units or fewer hidden units: 32 units, 64 units, and so
# on.**

# %% [markdown]
# In this case, will try with 8 and 32 hidden units to identify any trends.

# %%
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(8, activation="relu"),
    layers.Dense(8, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
 history = model.fit(partial_x_train,
            partial_y_train,
            epochs=20,
            batch_size=512,
            validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6763 - loss: 0.6374 - val_accuracy: 0.8385 - val_loss: 0.4928
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8849 - loss: 0.4269 - val_accuracy: 0.8632 - val_loss: 0.3907
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9072 - loss: 0.3224 - val_accuracy: 0.8812 - val_loss: 0.3250
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9196 - loss: 0.2598 - val_accuracy: 0.8836 - val_loss: 0.3017
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9353 - loss: 0.2153 - val_accuracy: 0.8879 - val_loss: 0.2862
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9408 - loss: 0.1850 - val_accuracy: 0.8863 - val_loss: 0.2843
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9496 - loss: 0.1651 - val_accuracy: 0.8869 - val_loss: 0.2794
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss- 8 hidden units")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy- 8 hidden units")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
history_dict = history.history

val_acc = history_dict['val_accuracy']
val_loss = history_dict['val_loss']

final_val_acc_21 = val_acc[-1]
final_val_loss_21 = val_loss[-1]

print(final_val_acc_21)
print(final_val_loss_21)
# Out:
# 0.8730999827384949
# 0.4695308208465576

# %% [markdown]
# With 32 hidden units:

# %%
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(32, activation="relu"),
    layers.Dense(32, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
 history = model.fit(partial_x_train,
            partial_y_train,
            epochs=20,
            batch_size=512,
            validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - accuracy: 0.6805 - loss: 0.5986 - val_accuracy: 0.8571 - val_loss: 0.3840
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.8888 - loss: 0.3277 - val_accuracy: 0.8805 - val_loss: 0.3079
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9175 - loss: 0.2341 - val_accuracy: 0.8893 - val_loss: 0.2773
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9417 - loss: 0.1752 - val_accuracy: 0.8835 - val_loss: 0.2938
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9489 - loss: 0.1516 - val_accuracy: 0.8864 - val_loss: 0.2872
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.9575 - loss: 0.1265 - val_accuracy: 0.8815 - val_loss: 0.3148
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9690 - loss: 0.1051 - val_accuracy: 0.8840 - val_loss: 0.3111
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss- 32 hidden units")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy- 32 hidden units")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
history_dict = history.history

val_acc = history_dict['val_accuracy']
val_loss = history_dict['val_loss']

final_val_acc_22 = val_acc[-1]
final_val_loss_22 = val_loss[-1]

print(final_val_acc_22)
print(final_val_loss_22)
# Out:
# 0.8745999932289124
# 0.5966763496398926

# %% [markdown]
# The accuracy rate is relatively similar for both 8 and 32 hidden units, but the validation loss is much lower for 8 hidden units.

# %% [markdown]
# **3. Try using the mse loss function instead of binary_crossentropy.**

# %%
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(optimizer='rmsprop',
              loss='mse',
              metrics=['accuracy'])

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
 history = model.fit(partial_x_train,
            partial_y_train,
            epochs=20,
            batch_size=512,
            validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - accuracy: 0.7107 - loss: 0.2034 - val_accuracy: 0.8473 - val_loss: 0.1309
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8841 - loss: 0.1067 - val_accuracy: 0.8572 - val_loss: 0.1118
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9150 - loss: 0.0794 - val_accuracy: 0.8767 - val_loss: 0.0951
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9333 - loss: 0.0635 - val_accuracy: 0.8854 - val_loss: 0.0865
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9411 - loss: 0.0556 - val_accuracy: 0.8851 - val_loss: 0.0861
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9481 - loss: 0.0481 - val_accuracy: 0.8775 - val_loss: 0.0906
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9569 - loss: 0.0411 - val_accuracy: 0.8802 - val_loss: 0.0879
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss- MSE")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy- MSE")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
history_dict = history.history

val_acc = history_dict['val_accuracy']
val_loss = history_dict['val_loss']

final_val_acc_3 = val_acc[-1]
final_val_loss_3 = val_loss[-1]

print(final_val_acc_3)
print(final_val_loss_3)
# Out:
# 0.8755999803543091
# 0.09818270057439804

# %% [markdown]
# Using MSE gave a relatively similar accuracy to the base model, but gave a substantially lower validaiton loss- the lowest validation loss for all hyperparameter tunings.

# %% [markdown]
# **4. Try using the tanh activation (an activation that was popular in the early days of neural
# networks) instead of relu.**

# %%
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(16, activation="tanh"),
    layers.Dense(16, activation="tanh"),
    layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
 history = model.fit(partial_x_train,
            partial_y_train,
            epochs=20,
            batch_size=512,
            validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.7002 - loss: 0.5737 - val_accuracy: 0.8709 - val_loss: 0.3588
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9058 - loss: 0.2938 - val_accuracy: 0.8759 - val_loss: 0.3081
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - accuracy: 0.9275 - loss: 0.2091 - val_accuracy: 0.8864 - val_loss: 0.2792
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9436 - loss: 0.1641 - val_accuracy: 0.8693 - val_loss: 0.3288
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9501 - loss: 0.1366 - val_accuracy: 0.8778 - val_loss: 0.3138
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9683 - loss: 0.0994 - val_accuracy: 0.8810 - val_loss: 0.3283
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9728 - loss: 0.0836 - val_accuracy: 0.8772 - val_loss: 0.3578
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss- tanh activation")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy- tanh activation")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
history_dict = history.history

val_acc = history_dict['val_accuracy']
val_loss = history_dict['val_loss']

final_val_acc_4 = val_acc[-1]
final_val_loss_4 = val_loss[-1]

print(final_val_acc_4)
print(final_val_loss_4)
# Out:
# 0.8655999898910522
# 0.7405454516410828

# %% [markdown]
# Using tanh activation produced both a slightly lower accuracy rate as well as a higher validation loss than the base model.

# %% [markdown]
# **5. Use any technique we studied in class, and these include regularization, dropout, etc., to
# get your model to perform better on validation.**

# %%
y_train = np.asarray(train_labels).astype("float32")
y_test = np.asarray(test_labels).astype("float32")

# %%
from tensorflow.keras import regularizers

model = keras.Sequential([
    layers.Dense(16, activation="relu",
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(16, activation="relu",
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
 history = model.fit(partial_x_train,
            partial_y_train,
            epochs=20,
            batch_size=512,
            validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.6931 - loss: 0.6506 - val_accuracy: 0.8455 - val_loss: 0.4705
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8865 - loss: 0.4101 - val_accuracy: 0.8802 - val_loss: 0.3775
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9158 - loss: 0.3132 - val_accuracy: 0.8758 - val_loss: 0.3608
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9310 - loss: 0.2687 - val_accuracy: 0.8848 - val_loss: 0.3369
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9398 - loss: 0.2355 - val_accuracy: 0.8852 - val_loss: 0.3339
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9466 - loss: 0.2187 - val_accuracy: 0.8845 - val_loss: 0.3339
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9554 - loss: 0.2012 - val_accuracy: 0.8820 - val_loss: 0.3457
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt
history_dict = history.history
loss_values = history_dict["loss"]
val_loss_values = history_dict["val_loss"]
epochs = range(1, len(loss_values) + 1)
plt.plot(epochs, loss_values, "bo", label="Training loss")
plt.plot(epochs, val_loss_values, "b", label="Validation loss")
plt.title("Training and validation loss- Regularization")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.clf()
acc = history_dict["accuracy"]
val_acc = history_dict["val_accuracy"]
plt.plot(epochs, acc, "bo", label="Training acc")
plt.plot(epochs, val_acc, "b", label="Validation acc")
plt.title("Training and validation accuracy- Regularization")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
history_dict = history.history

val_acc = history_dict['val_accuracy']
val_loss = history_dict['val_loss']

final_val_acc_5 = val_acc[-1]
final_val_loss_5 = val_loss[-1]

print(final_val_acc_5)
print(final_val_loss_5)
# Out:
# 0.8737999796867371
# 0.42944398522377014

# %% [markdown]
# Using regularization produced a similar accuracy to the base model, but also provided a lower validation loss.

# %% [markdown]
# **Findings**

# %%
import pandas as pd

data = {
    "Tuning": [
        "Base Model", "1 Hidden Layer", "3 Hidden Layers",
        "8 Hidden Units", "32 Hidden Units", "MSE",
        "Tanh", "Regularization"
    ],
    "Validation Accuracy": [
        0.8720999956130981, 0.8763999938964844, 0.8695999979972839,
        0.8730999827384949, 0.8745999932289124, 0.8755999803543091,
        0.8655999898910522, 0.8737999796867371
    ],
    "Validation Loss": [
        0.5604092478752136, 0.3762778639793396, 0.6332480907440186,
        0.4695308208465576, 0.5966763496398926, 0.09818270057439804,
        0.7405454516410828, 0.42944398522377014
    ]
}

df = pd.DataFrame(data)

df = df.round(2)

def highlight_best_only(s, col_name):
    if col_name == 'Validation Accuracy':
        return ['font-weight: bold' if v == s.max() else '' for v in s]
    elif col_name == 'Validation Loss':
        return ['font-weight: bold' if v == s.min() else '' for v in s]

df.style.apply(highlight_best_only, col_name='Validation Accuracy', subset=['Validation Accuracy'])\
       .apply(highlight_best_only, col_name='Validation Loss', subset=['Validation Loss'])
# Out:
# <style type="text/css">
# #T_41ab3_row1_col1, #T_41ab3_row5_col1, #T_41ab3_row5_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_41ab3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41ab3_level0_col0" class="col_heading level0 col0" >Tuning</th>
#       <th id="T_41ab3_level0_col1" class="col_heading level0 col1" >Validation Accuracy</th>
#       <th id="T_41ab3_level0_col2" class="col_heading level0 col2" >Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41ab3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41ab3_row0_col0" class="data row0 col0" >Base Model</td>
#       <td id="T_41ab3_row0_col1" class="data row0 col1" >0.870000</td>
#       <td id="T_41ab3_row0_col2" class="data row0 col2" >0.560000</td>
#     </tr>
#     <tr>
#       <th id="T_41ab3_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %% [markdown]
# Overall, adjusting the hyperparameters still resulted in fairly consistent validation accuracy. However, the validation loss varied widely throughout different tunings. The results are listed in the above table. While the validation accuracy was relatively consistent throughout, both the "1 Hidden Layer" and MSE tunings produced the highest accuracy. For validation loss, MSE was decisively the best performing (lowest) tuning. As a whole, it appears that the simpler tunings performed better than the more complex tunings, suggesting a simpler model with fewer hidden layers/units and incorporating MSE may be the best option.
